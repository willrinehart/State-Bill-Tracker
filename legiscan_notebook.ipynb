# %%
import requests
import pandas as pd
import time

API_KEY = "1e3f39af250dc10bbecb0b0e6ea4be66"
BASE_URL = "https://api.legiscan.com/"


def get_states():
    """
    Get the list of all states supported by LegiScan.
    Returns a list of state abbreviations.
    """
    url = f"{BASE_URL}?key={API_KEY}&op=getMasterList&state=US"
    resp = requests.get(url)
    resp.raise_for_status()
    data = resp.json()
    return list(data['masterlist'].keys())


def get_sessions(state):
    """
    Get the list of sessions for a given state.
    @param state
    @return a list of session_id.
    """
    url = f"{BASE_URL}?key={API_KEY}&op=getSessionList&state={state}"
    resp = requests.get(url)
    resp.raise_for_status()
    data = resp.json()
    return [s['session_id'] for s in data['sessions']]


def search_ai_bills(state, session_id):
    """
    Search for AI-related bills in a given state/session.
    @param state
    @param session_id
    @return a list of bill dictionaries.
    """
    url = f"{BASE_URL}?key={API_KEY}&op=search&state={state}&query=artificial+intelligence&session_id={session_id}"
    resp = requests.get(url)
    resp.raise_for_status()
    data = resp.json()
    bills = []
    searchresult = data.get('searchresult', {})
    for key, bill in searchresult.items():
        if key == "summary":
            continue
        # Add the state to the bill dictionary for reference
        bill['State'] = state
        bills.append(bill)
    return bills


def get_bill_details(bill_id):
    """
    Retrieve detailed information for a specific bill by bill_id.
    """
    url = f"{BASE_URL}?key={API_KEY}&op=getBill&id={bill_id}"
    resp = requests.get(url)
    resp.raise_for_status()
    data = resp.json()
    return data['bill']


def main():
    print("=== LegiScan AI Bill Extractor ===")
    all_bills = []
    states = [
        'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA',
        'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK',
        'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'
    ]
    for state in states:
        print(f"Searching {state}...")
        try:
            sessions = get_sessions(state)
            if not sessions:
                continue
            latest_session = sessions[-1]
            bills = search_ai_bills(state, latest_session)
            # Fetch and append description for each bill
            for bill in bills:
                try:
                    details = get_bill_details(bill['bill_id'])
                    bill['description'] = details.get('description', '')
                except Exception as e:
                    print(f"  Could not fetch details for bill {bill['bill_id']}: {e}")
                    bill['description'] = ''
                time.sleep(0.5)  # To avoid 429 error
            all_bills.extend(bills)
            time.sleep(1)  # To avoid 429 error
        except Exception as e:
            print(f"Error with state {state}: {e}")
            continue
    if not all_bills:
        print("No AI-related bills found.")
        return
    df = pd.DataFrame(all_bills)
    df.to_excel("ai_bills_legiscan.xlsx", index=False)
    print(f"Found {len(all_bills)} AI-related bills. Results saved to ai_bills_legiscan.xlsx")


if __name__ == "__main__":
    main()
# Out:
# === LegiScan AI Bill Extractor ===
# Searching AL...
# Searching AK...
# Searching AZ...
# Searching AR...
# Searching CA...
# Searching CO...
# Searching CT...
# Searching DE...
# Searching FL...
# Searching GA...
# Searching HI...
# Searching ID...
# Searching IL...
# Searching IN...
# Searching IA...
# Searching KS...
# Searching KY...
# Searching LA...
# Searching ME...
# Searching MD...
# Searching MA...
# Searching MI...
# Searching MN...
# Searching MS...
# Searching MO...
# Searching MT...
# Searching NE...
# Searching NV...
# Searching NH...
# Searching NJ...
# Searching NM...
# Searching NY...
# Searching NC...
# Searching ND...
# Searching OH...
# Searching OK...
# Searching OR...
#   Could not fetch details for bill 1973003: HTTPSConnectionPool(host='api.legiscan.com', port=443): Read timed out. (read timeout=None)
# Searching PA...
#   Could not fetch details for bill 2041064: HTTPSConnectionPool(host='api.legiscan.com', port=443): Read timed out. (read timeout=None)
# Searching RI...
# Searching SC...
#   Could not fetch details for bill 1954733: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   Could not fetch details for bill 2029172: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getBill&id=2029172 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263d90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#   Could not fetch details for bill 1944096: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getBill&id=1944096 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263fa0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#   Could not fetch details for bill 1895182: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getBill&id=1895182 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263fa0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#   Could not fetch details for bill 1919972: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getBill&id=1919972 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263fa0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#   Could not fetch details for bill 1895637: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getBill&id=1895637 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263fa0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching SD...
# Error with state SD: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=SD (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263fd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching TN...
# Error with state TN: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=TN (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263400>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching TX...
# Error with state TX: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=TX (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d2633d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching UT...
# Error with state UT: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=UT (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263970>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching VT...
# Error with state VT: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=VT (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d2608b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching VA...
# Error with state VA: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=VA (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263370>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching WA...
# Error with state WA: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=WA (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263310>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching WV...
# Error with state WV: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=WV (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263cd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching WI...
# Error with state WI: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=WI (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263d00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Searching WY...
# Error with state WY: HTTPSConnectionPool(host='api.legiscan.com', port=443): Max retries exceeded with url: /?key=1e3f39af250dc10bbecb0b0e6ea4be66&op=getSessionList&state=WY (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x11d263fa0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Found 775 AI-related bills. Results saved to ai_bills_legiscan.xlsx
